# %%
import pandas as pd

# %%
aha_df = pd.read_csv('./aha_data.csv')

pd.set_option('display.max_colwidth', None)
aha_df.head(10)
# Out:
#                                                                                                                                                   content
# 0                                         도마 위생적으로 관리하고 싶어요 어떻게 해야할가요? 요리하면서 도마를 가장 많이 사용하는데. 관리 잘못하면 음식 조리하면서 세균에 감염 될 수 도 있자나요. 도마 어떻게 위생적으로 관리를 해야할가요?
# 1                                                                          프라이팬으로 음식 볶을때, 기름 덜 튀게 할수 있을까요 음식 볶을때 기름이 많이 튀어서 불편 합니다. 덜 튀게 할수 있는 방법이 궁금합니다.
# 2                        집에서 스테이크를 만들려고 하는데.. 제가 집에서 스테이크를 처음으로 만들어 보려고 하는데요 그런데 모르는게 있는데 스테이크를 만들기 전에 고기의 밑간을 미리 해 놔야 하는 건가요? 그리고 고기는 프라이팬에 구워도 괜찮은 건가요?
# 3                                                          김치 자를때 도마에 물들지 않게 하려면? 김치를 도마위에 놓고 자르면 김칫국물이 스며들어서 보기 안좋은데요. 뻘건 김치국물이 물들지 않게 하려면 어떻게 하면  좋을까요?
# 4                             소고기 프라이팬 구울 때 기름을 계속 닦아 줘야 하나요? 제가 소고기를 프라이팬에 구워 본 적이 한 번도 없는데요 그런데 이번에 집에서 그냥 대충 구워 먹으려고 하는데 혹시 기름이 계속 나오면 닦아 주면서 구워야 하나요?
# ...

# %%
pan_df = aha_df[aha_df['content'].str.contains('프라이팬|후라이팬', case=False, na=False, regex=True)]
pan_df.head(10)
# Out:
#                                                                                                                                              content
# 1                                                                     프라이팬으로 음식 볶을때, 기름 덜 튀게 할수 있을까요 음식 볶을때 기름이 많이 튀어서 불편 합니다. 덜 튀게 할수 있는 방법이 궁금합니다.
# 2                   집에서 스테이크를 만들려고 하는데.. 제가 집에서 스테이크를 처음으로 만들어 보려고 하는데요 그런데 모르는게 있는데 스테이크를 만들기 전에 고기의 밑간을 미리 해 놔야 하는 건가요? 그리고 고기는 프라이팬에 구워도 괜찮은 건가요?
# 4                        소고기 프라이팬 구울 때 기름을 계속 닦아 줘야 하나요? 제가 소고기를 프라이팬에 구워 본 적이 한 번도 없는데요 그런데 이번에 집에서 그냥 대충 구워 먹으려고 하는데 혹시 기름이 계속 나오면 닦아 주면서 구워야 하나요?
# 6                                          홀랑태운 탄냄비나프라이팬을 세척하는 방법이 궁금합니다. 으씩하는 도중에 캄밖잊고 냄비및프라이팬을 태웠습니다. 홀랑태운 탄냄비나프라이팬을 세척하는 방법이 궁금합니다. 빠른시간에 해걸하는방법등
# 8                                     프라이팬은 몇 년 동안 써도 되는 건가요? 지금 집에서 프라이팬을 사다 놓으면 최소 3년 이상을 사용하는 거 같은데요 그런데 너무 오래 사용하면 안 좋다고 하는데 혹시 몇 년 동안 써도 괜찮을까요?
# ...

# %%
pan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 383 entries, 1 to 801
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  383 non-null    object
# dtypes: object(1)
# memory usage: 6.0+ KB

# %%
pan_df.to_csv("pan_aha.csv", index=False,encoding='utf-8-sig')
