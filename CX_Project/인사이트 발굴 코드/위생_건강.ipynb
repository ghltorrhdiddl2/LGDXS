# %%
import pandas as pd

# %%
df = pd.read_csv('./data/지식인아하디시_조리도구_통합.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3105 entries, 0 to 3104
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  3105 non-null   object
# dtypes: object(1)
# memory usage: 24.4+ KB

# %%
df.head()
# Out:
#                                              content
# 0  도마 위생적으로 관리하고 싶어요 어떻게 해야할가요? 요리하면서 도마를 가장 많이 사...
# 1  프라이팬으로 음식 볶을때, 기름 덜 튀게 할수 있을까요 음식 볶을때 기름이 많이 튀...
# 2  집에서 스테이크를 만들려고 하는데.. 제가 집에서 스테이크를 처음으로 만들어 보려고...
# 3  김치 자를때 도마에 물들지 않게 하려면? 김치를 도마위에 놓고 자르면 김칫국물이 스...
# 4  소고기 프라이팬 구울 때 기름을 계속 닦아 줘야 하나요? 제가 소고기를 프라이팬에 ...

# %%
pd.set_option('display.max_colwidth', None)
 
gomp = df[df['content'].str.contains('곰팡이', na=False)]
gomp.shape
# Out:
# (82, 1)

# %%
gomp.head(20)
# Out:
#                                                                                                                                                                                                 content
# 115                                                                                                 나무도마가 나을까요 플라스틱 도마가 나을까요? 나무도마가 나을까요 플라스틱 도마가 나을까요? 플라스틱 도마는 환경호르몬이 나올거같고 나무도마는 곰팡이가 껴서 둘중 뭐살지 고민돼요
# 155                                                                                 나무도마 곰팡이 제거방법이 있을까요? 락스를 뿌리고 물티슈로 덮어도 없어지지 않네요 나무도마 라서 곰팡이가 생기면 버려야 하는지 모르겠네요 ㅜㅜ 나무 도마 곰팡이 제거 방법이 있다면 답변좀 부탁 드립니다
# 176                                                                                                  나무도마 어떻게 하면 잘 관리할 수가 있나요? 나무도마를 쓰고나서 잘 못 관리를 하면 곰팡이가 피고, 썩고 그러하더라고요. 어떻게 하면 나무도마를 잘 관리할 수 가 있을까요??
# ...

# %%
gomp.tail(20)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     content
# ...

# %%
hormone = df[df['content'].str.contains('호르몬', na=False)]
hormone.shape
# Out:
# (10, 1)

# %%
hormone
# Out:
#                                                                                                                                                                                                                                                                                                                                                      content
# 115                                                                                                                                                                                                                                                      나무도마가 나을까요 플라스틱 도마가 나을까요? 나무도마가 나을까요 플라스틱 도마가 나을까요? 플라스틱 도마는 환경호르몬이 나올거같고 나무도마는 곰팡이가 껴서 둘중 뭐살지 고민돼요
# ...

# %%
cleanliness = df[df['content'].str.contains('청결', na=False)]
cleanliness.shape
# Out:
# (12, 1)

# %%
cleanliness
# Out:
#                                                                                                                                                                                                                        content
# 175                                                                                                                 도마를 청결하게 유지할 수 있는 꿀팁있을까요? 평소에 집에서 요리를 굉장히 자주해먹는편이어서 칼질을 많이하다보니 도마사용 빈도가 많습니다. 도마를 청결하게 유지할 수 있는 비결이 있으신가요?
# 356                                                  주방에서 사용하는 나무 도마는 어떻게 살균을 해야 하는 걸까요? 저희 집에는 도마가 나무로 되어 있습니다. 그런데 도마를 사용하고 나면 항상 음식물 자국이 스며 드는것 같아서 자주 교체를 하는 편입니다. 그리고 도마는 항상 청결해야 할것 같은데 대체로 나무로 된 도마는 어떻게 살균을 해야 좋은 걸까요?
# 375                                                                                       나무도마 상처는 어떻게 관리해야하나요? 집에서 나무로 된 도마를 사용하고있는데요. 아무래도 나무이다 보니깐, 칼자국이라던지 상처가 많이 나서요. 그 틈으로 곰팡이나 세균이 생길 수도 있다고 하던데, 청결하게 관리를 어떻게 해줘야 할까요?
# ...

# %%
wesang = df[df['content'].str.contains('위생', na=False)]
wesang.shape
# Out:
# (102, 1)

# %%
wesang.head(15)
# Out:
#                                                                                                                                                                                                                                                     content
# 0                                                                                                                                           도마 위생적으로 관리하고 싶어요 어떻게 해야할가요? 요리하면서 도마를 가장 많이 사용하는데. 관리 잘못하면 음식 조리하면서 세균에 감염 될 수 도 있자나요. 도마 어떻게 위생적으로 관리를 해야할가요?
# 17                                                                                                                                                    용도별로 도마를 따로 사용하는 게 위생적일까요? 고기는 고기대로 야채는 야채대로 따로 썰어서 사용하는 게 위생적인데 특히 고기 썬 도마는 씻어도 비위생적일 거 같아서 항상 삶습니다.
# ...

# %%
wesang.tail(15)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        content
# ...

# %%
health = df[df['content'].str.contains('건강', na=False)]
health.shape
# Out:
# (40, 1)

# %%
health.head(20)
# Out:
#                                                                                                                                                                                                                                                                                                                                                     content
# 99                                                                                                                                                                                                                                       프라이팬 실리콘 코팅 살짝 벗겨진것도 사용하면 안되나요? 안녕하세요?   휴일은 편안하셨나요?   저녁을 준비하려는데 프라이퍈 실리콘 코팅이 조금 벗겨졌는데 사용하면 안되나요?  건강에 안좋다고 하던데.
# ...
