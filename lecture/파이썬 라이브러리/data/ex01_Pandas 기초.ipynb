# %% [markdown]
# ### 학습목표
# - 데이터분석 프로세스를 이해할 수 있다
# - Pandas의 기본 사용법을 익히고 활용할 수 있다

# %% [markdown]
# ## 1. 데이터 분석 프로세스
#
# <img src="attachment:0bfa914b-ace2-44ee-a0fd-048a8dfdec9c.png" width="590" height="590"/>

# %% [markdown]
# ## 2. Pandas 구조 이해하기
# - Series : 1차원 데이터를 표현하는 데이터타입
# - DataFrame : 2차원 데이터를 표현하는 데이터타입

# %% [markdown]
# ![image.png](attachment:cc335653-1ef0-4c84-b1a9-1b55312e91c0.png)![image.png](attachment:fc9d904c-b0c5-4a90-b9b6-fd497431fb0b.png)

# %% [markdown]
# ### Series 생성

# %%
# 라이브러리(패키지) 설치
# !pip install pandas

# %%
import pandas as pd

team_name = pd.Series(['손지영','서보경','황해도','김미희'])
team_name
# Out:
# 0    손지영
# 1    서보경
# 2    황해도
# 3    김미희
# dtype: object

# %%
# 시리즈의 데이터타입 변경하기
# int8, int16, float32, float64 -> 숫자로 변경 가능
team_name_str = team_name.astype('string') # 문자열 타입으로 변경
team_name_str
# Out:
# 0    손지영
# 1    서보경
# 2    황해도
# 3    김미희
# dtype: string
