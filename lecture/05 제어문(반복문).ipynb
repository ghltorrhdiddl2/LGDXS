# %% [markdown]
# ## while 문

# %% [markdown]
# <img src="attachment:46a1494c-f98c-469c-8ce9-8a322393a357.png" width="590" height="590"/>

# %% [markdown]
# ## 반복문
# - 프로그램 실행문장을 반복적으로 수행하고 싶은 경우 활용하는 문법
# - 불필요한 코드를 줄이고 간결하게 만들어주서 가독성을 높여주는 효과
# - while : 반복 횟수가 정해지지 않은 경우
# - for : 반복 횟수가 명확한 경우

# %% [markdown]
# ### while 활용하기
# - 파이썬 최고!!를 13번 출력하는 문장을 구성하자

# %%
cnt=1

while cnt<=13:
    print('파이썬 최고!!', cnt)
    cnt += 1
# Out:
# 파이썬 최고!! 1
# 파이썬 최고!! 2
# 파이썬 최고!! 3
# 파이썬 최고!! 4
# 파이썬 최고!! 5
# 파이썬 최고!! 6
# 파이썬 최고!! 7
# 파이썬 최고!! 8
# 파이썬 최고!! 9
# 파이썬 최고!! 10
# 파이썬 최고!! 11
# 파이썬 최고!! 12
# 파이썬 최고!! 13

# %%
# 무한반복 구조와 break 활용하기
cnt = 1

while True:
    print('파이썬 최고!!', cnt)
    cnt += 1
    if cnt > 13: break # 반복을 중단하는 명령어
# Out:
# 파이썬 최고!! 1
# 파이썬 최고!! 2
# 파이썬 최고!! 3
# 파이썬 최고!! 4
# 파이썬 최고!! 5
# 파이썬 최고!! 6
# 파이썬 최고!! 7
# 파이썬 최고!! 8
# 파이썬 최고!! 9
# 파이썬 최고!! 10
# 파이썬 최고!! 11
# 파이썬 최고!! 12
# 파이썬 최고!! 13

# %%
# 두개의 정수를 입력 받아서 더하는 코드
# 조건 : 두개의 정수가 0이 들어올때까지 반복

a = 1; b = 1

while True:
    if a == 0 and b == 0:
        print('프로그램이 종료되었습니다.')
        break
    a = int(input('첫 번째 정수 입력 >> '))
    b = int(input('두 번째 정수 입력 >> '))

    print('두 정수의 합 :', a+b)
# Out:
# 첫 번째 정수 입력 >>  1
# 두 번째 정수 입력 >>  2
# 두 정수의 합 : 3
# 첫 번째 정수 입력 >>  0
# 두 번째 정수 입력 >>  0
# 두 정수의 합 : 0
# 프로그램이 종료되었습니다.

# %%
while True:
    a = int(input('첫 번째 정수 입력 >> '))
    b = int(input('두 번째 정수 입력 >> '))
    if a == 0 and b == 0:
        print('프로그램이 종료되었습니다.')
        break

    print('두 정수의 합 :', a+b)
# Out:
# 첫 번째 정수 입력 >>  1
# 두 번째 정수 입력 >>  2
# 두 정수의 합 : 3
# 첫 번째 정수 입력 >>  0
# 두 번째 정수 입력 >>  0
# 프로그램이 종료되었습니다.

# %%
import random

num = random.randint(1, 50)
print(num)

while True:
    user = int(input('숫자를 입력하세요 >> '))
    if num < user:
        print(f'{user}보다 작은 수 입니다.')
    elif num > user:
        print(f'{user}보다 큰 수 입니다.')
    else:
        print('정답을 맞추셨습니다.')
        break
# Out:
# 22
# 숫자를 입력하세요 >>  20
# 20보다 큰 수 입니다.
# 숫자를 입력하세요 >>  24
# 24보다 작은 수 입니다.
# 숫자를 입력하세요 >>  22
# 정답을 맞추셨습니다.

# %%
curr = int(input('현재 몸무게 : '))
goal = int(input('목표 몸무게 : '))
cnt = 0

while True:
    cnt += 1
    minus = int(input(f'{cnt}주차 감량 몸무게 : '))
    curr -= minus
    if curr <= goal:
        print(f'{curr}kg 달성!! 축하합니다!')
        break
# Out:
# 현재 몸무게 :  80
# 목표 몸무게 :  70
# 1주차 감량 몸무게 :  2
# 2주차 감량 몸무게 :  3
# 3주차 감량 몸무게 :  4
# 4주차 감량 몸무게 :  5
# 66kg 달성!! 축하합니다!

# %%
list = ['딸기','바나나','수박','체리','포도']

print('*'*40)
s = input('검색할 문자를 입력하세요 >> ')
if s not in list:
    print(f'{s}는 리스트에 들어있지 않습니다.')
else: print(f'{s}는 리스트에 {list.index(s)}번째 인덱스에 들어있습니다.')
print('*'*40)
# Out:
# *********************************
# 검색할 문자를 입력하세요 >>  오렌지
# 오렌지는 리스트에 들어있지 않습니다.
# *********************************

# %%
s = 'Hi, My name is Mihee'  # 20개 문자
# print(len(s))
cnt = 0
duplication = 0
print('*'*40)
c = input('검색할 문자를 입력하세요 : ')

while cnt < len(s):
    if s[cnt] == c:
        duplication += 1
    cnt += 1
    
if duplication != 0:
    print(f'{c}는 {duplication} 번 들어 있습니다.')
else:
    print(f'{c}는 문자열에 들어있지 않습니다.')

print('*'*40)
# Out:
# ****************************************
# 검색할 문자를 입력하세요 :  i
# i는 3 번 들어 있습니다.
# ****************************************

# %%
s = 'Hi, My name is Mihee'  # 20개 문자
c = input('검색할 문자를 입력하세요 : ')

print('*'*40)
if cnt != 0:
    print(f'{c}는 {s.count(c)}번 들어 있습니다.')
else:
    print(f'{c}는 문자열에 들어있지 않습니다.')
print('*'*40)
# Out:
# 검색할 문자를 입력하세요 :  i
# ****************************************
# i는 3번 들어 있습니다.
# ****************************************

# %%
import random

customer = 1
o = 0

while customer < 51:
    time = random.randint(5,50)
    if time >= 5 and time <= 15:
        print(f'[0] {customer}번째 손님 (소요시간 : {time}분)')
        o += 1
    else:
        print(f'[ ] {customer}번째 손님 (소요시간 : {time}분)')
    customer += 1

print(f'총 탑승객 : {o}명')
# Out:
# [0] 1번째 손님 (소요시간 : 6분)
# [ ] 2번째 손님 (소요시간 : 33분)
# [ ] 3번째 손님 (소요시간 : 30분)
# [ ] 4번째 손님 (소요시간 : 29분)
# [ ] 5번째 손님 (소요시간 : 36분)
# [ ] 6번째 손님 (소요시간 : 23분)
# [ ] 7번째 손님 (소요시간 : 18분)
# [0] 8번째 손님 (소요시간 : 10분)
# [ ] 9번째 손님 (소요시간 : 38분)
# [ ] 10번째 손님 (소요시간 : 32분)
# [ ] 11번째 손님 (소요시간 : 41분)
# [ ] 12번째 손님 (소요시간 : 26분)
# [ ] 13번째 손님 (소요시간 : 48분)
# [0] 14번째 손님 (소요시간 : 13분)
# [ ] 15번째 손님 (소요시간 : 31분)
# [ ] 16번째 손님 (소요시간 : 23분)
# [ ] 17번째 손님 (소요시간 : 31분)
# [ ] 18번째 손님 (소요시간 : 25분)
# [ ] 19번째 손님 (소요시간 : 47분)
# [ ] 20번째 손님 (소요시간 : 42분)
# [0] 21번째 손님 (소요시간 : 8분)
# [0] 22번째 손님 (소요시간 : 5분)
# [ ] 23번째 손님 (소요시간 : 25분)
# [ ] 24번째 손님 (소요시간 : 31분)
# [ ] 25번째 손님 (소요시간 : 35분)
# [0] 26번째 손님 (소요시간 : 8분)
# [ ] 27번째 손님 (소요시간 : 34분)
# [0] 28번째 손님 (소요시간 : 14분)
# [ ] 29번째 손님 (소요시간 : 19분)
# [ ] 30번째 손님 (소요시간 : 32분)
# [ ] 31번째 손님 (소요시간 : 20분)
# [0] 32번째 손님 (소요시간 : 9분)
# [ ] 33번째 손님 (소요시간 : 18분)
# [ ] 34번째 손님 (소요시간 : 40분)
# [ ] 35번째 손님 (소요시간 : 48분)
# [ ] 36번째 손님 (소요시간 : 31분)
# [ ] 37번째 손님 (소요시간 : 23분)
# ...

# %% [markdown]
# ## for문
#
# <img src="attachment:647e2c23-70e4-48ae-9a24-2be02b201918.png" width="590" height="590"/>
#
# - for문에서 반복가능한 대상 이해하기

# %%
list_food = ['뉴치케','엄마는외계인','민트초코','초코초코']
list_food
# Out:
# ['뉴치케', '엄마는외계인', '민트초코', '초코초코']

# %%
cnt = 1 # 카운팅 변수 설정

for i in list_food:
    print(cnt, i)
    cnt += 1

# 반복횟수 4번! List의 길이 만큼
# Out:
# 1 뉴치케
# 2 엄마는외계인
# 3 민트초코
# 4 초코초코

# %%
# 튜플, 문자열, 딕셔너리, 집합
tup = (1,2,3,4,5)
for i in tup:
    print(i, end=' ')

print()

str = '점심 이후에는 조금 졸려요~'
for i in str:
    print(i)

print()

dic = {'a':1, 'b':2, 'c':3}
for i in dic:
    print(i, end=' ')   #==> 딕셔너리는 key값만 출력됨!
for i in dic.values():  # ==> .values()로 value값 출력 가능!
    print(i, end=' ')  

print()

com = {3,1,3}   #==> 집합은 결과에서 중복 제거해줌
for i in com:
    print(i, end=' ')
# Out:
# 1 2 3 4 5
# 점
# 심
#
# 이
# 후
# 에
# 는
#
# 조
# 금
#
# 졸
# 려
# 요
# ~
#
# a b c 1 2 3
# 1 3

# %% [markdown]
# - 집합 { } --> 여러개 데이터를 모아둔 상황에서 중복을 제거하고 데이터 정리하고 싶을 때(필터링 가능)

# %%
list1 = [1,2,1,2,3,5,2]
set(list1)
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# - 필터링

# %%
score_list = [90,45,70,60,55]
cnt = 1

for i in score_list:
    if i >= 60:
        print(f'{cnt}번 학생은 합격입니다.')
    else:
        print(f'{cnt}번 학생은 불합격입니다.')
    cnt += 1
# Out:
# 1번 학생은 합격입니다.
# 2번 학생은 불합격입니다.
# 3번 학생은 합격입니다.
# 4번 학생은 합격입니다.
# 5번 학생은 불합격입니다.

# %%
score_list = [90,45,70,60,55]

for i, v in enumerate(score_list):
    if v >= 60:
        print(f'{i+1}번 학생은 합격입니다.')
    else:
        print(f'{i+1}번 학생은 불합격입니다.')
# Out:
# 1번 학생은 합격입니다.
# 2번 학생은 불합격입니다.
# 3번 학생은 합격입니다.
# 4번 학생은 합격입니다.
# 5번 학생은 불합격입니다.

# %%
list2 = [[1,'황재호'],[2,'신현준'],[3,'기나영'],[4,'박원지'],[5,'이혜영']]

for i in list2:
    # print(i[1])
    print(f'{i[0]}번 사람은 {i[1]} 입니다.')
# Out:
# 1번 사람은 황재호 입니다.
# 2번 사람은 신현준 입니다.
# 3번 사람은 기나영 입니다.
# 4번 사람은 박원지 입니다.
# 5번 사람은 이혜영 입니다.

# %% [markdown]
# - for문과 자주 사용하는 range()
#   - 필요한 만큼의 숫자를 만들어내는 유용한 기능
#   - range(시작할 숫자, 종료할 숫자, 증감량)
#   - range(1,10,1) -> 1부터 9까지 1씩 증가
#   - range(10,1,-1) -> 10부터 2까지 1씩 감소

# %%
score_list = [90,45,70,60,55]
# range 함수를 사용해서 score_list를 반복시키기
# range 생성하는 숫자는 인덱스 번호로 활용될 수 있음

for i in range(0,len(score_list),1):
    print(score_list[i])
# Out:
# 90
# 45
# 70
# 60
# 55
