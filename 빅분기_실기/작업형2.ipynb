# %%
import pandas as pd

train = pd.read_csv("./part2/ch2/train.csv")
test = pd.read_csv("./part2/ch2/test.csv")
train.head(3)
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0   3331  34.0  State-gov  177331  Some-college             10
# 1  19749  58.0    Private  290661       HS-grad              9
# 2   1157  48.0    Private  125933  Some-college             10
#
#        marital.status       occupation relationship   race     sex  \
# 0  Married-civ-spouse   Prof-specialty      Husband  Black    Male
# 1  Married-civ-spouse     Craft-repair      Husband  White    Male
# 2             Widowed  Exec-managerial    Unmarried  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          4386             0            40.0  United-States   >50K
# 1             0             0            40.0  United-States  <=50K
# 2             0          1669            38.0  United-States  <=50K

# %%
test.head(3)
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0  11574  39.0  State-gov  114055     Bachelors             13
# 1  15847  38.0    Private  254114  Some-college             10
# 2  17655  44.0  State-gov   55395       HS-grad              9
#
#           marital.status       occupation   relationship   race     sex  \
# 0          Never-married  Exec-managerial  Not-in-family  White  Female
# 1  Married-spouse-absent   Prof-specialty      Own-child  Black  Female
# 2          Never-married     Craft-repair  Not-in-family  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country
# 0             0             0            40.0  United-States
# 1             0             0            40.0  United-States
# 2             0             0             NaN  United-States

# %%
train.shape, test.shape
# Out:
# ((29304, 16), (3257, 15))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29304 entries, 0 to 29303
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              29304 non-null  int64
#  1   age             29292 non-null  float64
#  2   workclass       27642 non-null  object
#  3   fnlwgt          29304 non-null  int64
#  4   education       29304 non-null  object
#  5   education.num   29304 non-null  int64
#  6   marital.status  29304 non-null  object
#  7   occupation      27636 non-null  object
#  8   relationship    29304 non-null  object
#  9   race            29304 non-null  object
#  10  sex             29304 non-null  object
#  11  capital.gain    29304 non-null  int64
#  12  capital.loss    29304 non-null  int64
#  13  hours.per.week  29291 non-null  float64
#  14  native.country  28767 non-null  object
#  15  income          29304 non-null  object
# dtypes: float64(2), int64(5), object(9)
# memory usage: 3.6+ MB

# %%
train.describe()
# Out:
#                  id           age        fnlwgt  education.num  capital.gain  \
# count  29304.000000  29292.000000  2.930400e+04   29304.000000  29304.000000
# mean   16264.027880     38.553223  1.897488e+05      10.080842   1093.858722
# std     9384.518323     13.628811  1.055250e+05       2.570824   7477.435640
# min        0.000000    -38.000000  1.228500e+04       1.000000      0.000000
# 25%     8145.750000     28.000000  1.177890e+05       9.000000      0.000000
# 50%    16253.500000     37.000000  1.783765e+05      10.000000      0.000000
# 75%    24374.250000     48.000000  2.370682e+05      12.000000      0.000000
# max    32560.000000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count  29304.000000    29291.000000
# mean      86.744506       40.434229
# std      401.518928       12.324036
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
print('처리전:', train.shape)
df = train.dropna()
print('처리후:',df.shape)
# Out:
# 처리전: (29304, 16)
# 처리후: (27096, 16)

# %%
train.head(3)
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0   3331  34.0  State-gov  177331  Some-college             10
# 1  19749  58.0    Private  290661       HS-grad              9
# 2   1157  48.0    Private  125933  Some-college             10
#
#        marital.status       occupation relationship   race     sex  \
# 0  Married-civ-spouse   Prof-specialty      Husband  Black    Male
# 1  Married-civ-spouse     Craft-repair      Husband  White    Male
# 2             Widowed  Exec-managerial    Unmarried  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          4386             0            40.0  United-States   >50K
# 1             0             0            40.0  United-States  <=50K
# 2             0          1669            38.0  United-States  <=50K

# %%
df = train.dropna(subset=['native.country','workclass'])
df.isnull().sum()
# Out:
# id                 0
# age               12
# workclass          0
# fnlwgt             0
# education          0
# education.num      0
# marital.status     0
# occupation         6
# relationship       0
# race               0
# sex                0
# capital.gain       0
# capital.loss       0
# hours.per.week    13
# native.country     0
# income             0
# dtype: int64

# %%
print('처리전: ', train.shape)
df = train.drop(['native.country','workclass'], axis=1)
print('처리후: ', df.shape)
# Out:
# 처리전:  (29304, 16)
# 처리후:  (29304, 14)

# %%
m = train['workclass'].mode()[0]
m
# Out:
# 'Private'

# %%
train.isnull().sum()
# Out:
# id                   0
# age                 12
# workclass         1662
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week      13
# native.country     537
# income               0
# dtype: int64

# %%
train['workclass'] = train['workclass'].fillna(m)
m2 = train['native.country'].mode()[0]
m2
# Out:
# 'United-States'

# %%
train['native.country'] = train['native.country'].fillna(m2)
train.isnull().sum()
# Out:
# id                   0
# age                 12
# workclass            0
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week      13
# native.country       0
# income               0
# dtype: int64

# %%
train['occupation'] = train['occupation'].fillna('X')
train.isnull().sum()
# Out:
# id                 0
# age               12
# workclass          0
# fnlwgt             0
# education          0
# education.num      0
# marital.status     0
# occupation         0
# relationship       0
# race               0
# sex                0
# capital.gain       0
# capital.loss       0
# hours.per.week    13
# native.country     0
# income             0
# dtype: int64

# %%
# test 데이터에도 같은 전처리 적용
test['workclass'] = test['workclass'].fillna(train['workclass'].mode()[0])
test['native.country'] = test['native.country'].fillna(train['native.country'].mode()[0])
test['occupation'] = test['occupation'].fillna('X')
test.isnull().sum()
# Out:
# id                0
# age               6
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    9
# native.country    0
# dtype: int64

# %%
value = int(train['age'].mean())
print('평균값 ', value)
train['age'] = train['age'].fillna(value)
test['age'] = test['age'].fillna(value)
# Out:
# 평균값  38

# %%
value2 = int(train['hours.per.week'].median())
print('중앙값 ', value2)
train['hours.per.week'] = train['hours.per.week'].fillna(value2)
test['hours.per.week'] = test['hours.per.week'].fillna(value2)
# Out:
# 중앙값  40

# %%
train.isnull().sum()
# Out:
# id                0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
train.describe()
# Out:
#                  id           age        fnlwgt  education.num  capital.gain  \
# count  29304.000000  29304.000000  2.930400e+04   29304.000000  29304.000000
# mean   16264.027880     38.552996  1.897488e+05      10.080842   1093.858722
# std     9384.518323     13.626025  1.055250e+05       2.570824   7477.435640
# min        0.000000    -38.000000  1.228500e+04       1.000000      0.000000
# 25%     8145.750000     28.000000  1.177890e+05       9.000000      0.000000
# 50%    16253.500000     37.000000  1.783765e+05      10.000000      0.000000
# 75%    24374.250000     48.000000  2.370682e+05      12.000000      0.000000
# max    32560.000000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count  29304.000000    29304.000000
# mean      86.744506       40.434036
# std      401.518928       12.321306
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
train[train['age']<=0]
# Out:
#           id   age workclass  fnlwgt     education  education.num  \
# 39     29188 -33.0   Private  263561  Some-college             10
# 79     14325 -38.0   Private   22245       HS-grad              9
# 26161   4292 -25.0   Private  200681  Some-college             10
#
#            marital.status       occupation relationship   race   sex  \
# 39     Married-civ-spouse     Craft-repair      Husband  White  Male
# 79     Married-civ-spouse  Exec-managerial      Husband  White  Male
# 26161       Never-married                X    Own-child  White  Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 39                0             0            60.0  United-States   >50K
# 79                0             0            60.0  United-States   >50K
# 26161             0             0            40.0  United-States  <=50K

# %% [markdown]
# - age 컬럼에 음수 있음!

# %%
test[test['age']<=0]
# Out:
# Empty DataFrame
# Columns: [id, age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country]
# Index: []

# %%
print(train.shape)
train = train[train['age']>0]
print(train.shape)
# Out:
# (29304, 16)
# (29301, 16)

# %%
train.head()
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0   3331  34.0  State-gov  177331  Some-college             10
# 1  19749  58.0    Private  290661       HS-grad              9
# 2   1157  48.0    Private  125933  Some-college             10
# 3    693  58.0    Private  100313  Some-college             10
# 4  12522  41.0    Private  195661  Some-college             10
#
#        marital.status        occupation relationship   race     sex  \
# 0  Married-civ-spouse    Prof-specialty      Husband  Black    Male
# 1  Married-civ-spouse      Craft-repair      Husband  White    Male
# 2             Widowed   Exec-managerial    Unmarried  Black  Female
# 3  Married-civ-spouse   Protective-serv      Husband  White    Male
# 4  Married-civ-spouse  Transport-moving      Husband  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          4386             0            40.0  United-States   >50K
# 1             0             0            40.0  United-States  <=50K
# 2             0          1669            38.0  United-States  <=50K
# 3             0          1902            40.0  United-States   >50K
# 4             0             0            54.0  United-States  <=50K

# %%
test.head()
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0  11574  39.0  State-gov  114055     Bachelors             13
# 1  15847  38.0    Private  254114  Some-college             10
# 2  17655  44.0  State-gov   55395       HS-grad              9
# 3  19790  47.0    Private   28035     Bachelors             13
# 4  31812  62.0    Private  186611       HS-grad              9
#
#           marital.status       occupation   relationship   race     sex  \
# 0          Never-married  Exec-managerial  Not-in-family  White  Female
# 1  Married-spouse-absent   Prof-specialty      Own-child  Black  Female
# 2          Never-married     Craft-repair  Not-in-family  White    Male
# 3     Married-civ-spouse  Exec-managerial        Husband  White    Male
# 4          Never-married                X  Not-in-family  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country
# 0             0             0            40.0  United-States
# 1             0             0            40.0  United-States
# 2             0             0            40.0  United-States
# 3             0             0            50.0  United-States
# 4             0             0            40.0  United-States

# %%
y_train = train.pop('income')

# %%
print(train.shape, test.shape)
data = pd.concat([train,test], axis=0)
data_oh = pd.get_dummies(data)
train_oh = data_oh.iloc[:len(train)].copy()
test_oh = data_oh.iloc[len(train):].copy()
print(train_oh.shape, test_oh.shape)
# Out:
# (29301, 15) (3257, 15)
# (29301, 107) (3257, 107)

# %%
cols = train.select_dtypes(include='object').columns
cols
# Out:
# Index(['workclass', 'education', 'marital.status', 'occupation',
#        'relationship', 'race', 'sex', 'native.country'],
#       dtype='object')

# %%
cols = ['workclass','education','marital.status','occupation','relationship','race','sex','native.country']
cols
# Out:
# ['workclass',
#  'education',
#  'marital.status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native.country']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    test[col] = le.transform(test[col])

train.head()
# Out:
#       id   age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   3331  34.0          6  177331         15             10               2
# 1  19749  58.0          3  290661         11              9               2
# 2   1157  48.0          3  125933         15             10               6
# 3    693  58.0          3  100313         15             10               2
# 4  12522  41.0          3  195661         15             10               2
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           9             0     2    1          4386             0
# 1           2             0     4    1             0             0
# 2           3             4     2    0             0          1669
# 3          10             0     4    1             0          1902
# 4          13             0     4    1             0             0
#
#    hours.per.week  native.country
# 0            40.0              38
# 1            40.0              38
# 2            38.0              38
# 3            40.0              38
# 4            54.0              38

# %%
train.describe()
# Out:
#                  id           age     workclass        fnlwgt     education  \
# count  29301.000000  29301.000000  29301.000000  2.930100e+04  29301.000000
# mean   16264.061568     38.560220      3.096823  1.897516e+05     10.302993
# std     9384.427564     13.607899      1.105128  1.055250e+05      3.863393
# min        0.000000     17.000000      0.000000  1.228500e+04      0.000000
# 25%     8146.000000     28.000000      3.000000  1.177890e+05      9.000000
# 50%    16254.000000     37.000000      3.000000  1.783700e+05     11.000000
# 75%    24374.000000     48.000000      3.000000  2.370650e+05     12.000000
# max    32560.000000     90.000000      7.000000  1.484705e+06     15.000000
#
#        education.num  marital.status    occupation  relationship  \
# count   29301.000000    29301.000000  29301.000000  29301.000000
# mean       10.080885        2.611583      6.425412      1.451725
# std         2.570948        1.506872      4.331550      1.609369
# min         1.000000        0.000000      0.000000      0.000000
# 25%         9.000000        2.000000      3.000000      0.000000
# 50%        10.000000        2.000000      6.000000      1.000000
# 75%        12.000000        4.000000     10.000000      3.000000
# max        16.000000        6.000000     14.000000      5.000000
#
#                race           sex  capital.gain  capital.loss  hours.per.week  \
# count  29301.000000  29301.000000  29301.000000  29301.000000    29301.000000
# mean       3.665028      0.668066   1093.970718     86.753387       40.432716
# std        0.849438      0.470916   7477.810241    401.538524       12.320876
# min        0.000000      0.000000      0.000000      0.000000        1.000000
# 25%        4.000000      0.000000      0.000000      0.000000       40.000000
# 50%        4.000000      1.000000      0.000000      0.000000       40.000000
# 75%        4.000000      1.000000      0.000000      0.000000       45.000000
# max        4.000000      1.000000  99999.000000   4356.000000       99.000000
#
#        native.country
# count    29301.000000
# mean        36.418723
# std          6.056322
# min          0.000000
# 25%         38.000000
# 50%         38.000000
# 75%         38.000000
# max         40.000000

# %%
cols = ['age','fnlwgt','education.num','capital.gain','capital.loss','hours.per.week']
def get_data():
    train_copy = train.copy()
    test_copy = test.copy()
    return train_copy, test_copy

# %%
train_copy, test_copy = get_data()

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_copy[cols] = scaler.fit_transform(train_copy[cols])
test_copy[cols] = scaler.transform(test_copy[cols])
train_copy[cols].head()
# Out:
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0  0.232877  0.112092       0.600000       0.04386      0.000000
# 1  0.561644  0.189060       0.533333       0.00000      0.000000
# 2  0.424658  0.077184       0.600000       0.00000      0.383150
# 3  0.561644  0.059785       0.600000       0.00000      0.436639
# 4  0.328767  0.124541       0.600000       0.00000      0.000000
#
#    hours.per.week
# 0        0.397959
# 1        0.397959
# 2        0.377551
# 3        0.397959
# 4        0.540816

# %%
train_copy.head()
# Out:
#       id       age  workclass    fnlwgt  education  education.num  \
# 0   3331  0.232877          6  0.112092         15       0.600000
# 1  19749  0.561644          3  0.189060         11       0.533333
# 2   1157  0.424658          3  0.077184         15       0.600000
# 3    693  0.561644          3  0.059785         15       0.600000
# 4  12522  0.328767          3  0.124541         15       0.600000
#
#    marital.status  occupation  relationship  race  sex  capital.gain  \
# 0               2           9             0     2    1       0.04386
# 1               2           2             0     4    1       0.00000
# 2               6           3             4     2    0       0.00000
# 3               2          10             0     4    1       0.00000
# 4               2          13             0     4    1       0.00000
#
#    capital.loss  hours.per.week  native.country
# 0      0.000000        0.397959              38
# 1      0.000000        0.397959              38
# 2      0.383150        0.377551              38
# 3      0.436639        0.397959              38
# 4      0.000000        0.540816              38

# %%
train_copy, test_copy = get_data()

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_copy[cols] = scaler.fit_transform(train_copy[cols])
test_copy[cols] = scaler.transform(test_copy[cols])
train_copy[cols].head()
# Out:
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0 -0.335121 -0.117705      -0.031462      0.440247     -0.216056
# 1  1.428590  0.956277      -0.420430     -0.146298     -0.216056
# 2  0.693710 -0.604783      -0.031462     -0.146298      3.940528
# 3  1.428590 -0.847573      -0.031462     -0.146298      4.520806
# 4  0.179295  0.056001      -0.031462     -0.146298     -0.216056
#
#    hours.per.week
# 0       -0.035121
# 1       -0.035121
# 2       -0.197450
# 3       -0.035121
# 4        1.101181

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
train[cols] = scaler.fit_transform(train[cols])
test[cols] = scaler.transform(test[cols])
train[cols].head()
# Out:
#     age    fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0 -0.15 -0.008711       0.000000        4386.0           0.0             0.0
# 1  1.05  0.941438      -0.333333           0.0           0.0             0.0
# 2  0.55 -0.439627       0.000000           0.0        1669.0            -0.4
# 3  1.05 -0.654423       0.000000           0.0        1902.0             0.0
# 4  0.20  0.144966       0.000000           0.0           0.0             2.8

# %%
y_train.value_counts()
# Out:
# income
# <=50K    22262
# >50K      7039
# Name: count, dtype: int64

# %%
y_train.head()
# Out:
# 0     >50K
# 1    <=50K
# 2    <=50K
# 3     >50K
# 4    <=50K
# Name: income, dtype: object

# %%
target = y_train.map({'<=50K':0, '>50K':1})
target.value_counts()
# Out:
# income
# 0    22262
# 1     7039
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(train, y_train, test_size=0.2, random_state=0)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((23440, 15), (5861, 15), (23440,), (5861,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)
pred = rf.predict_proba(X_val)

print(rf.classes_)
print(pred[:10])
# Out:
# ['<=50K' '>50K']
# [[1.   0.  ]
#  [1.   0.  ]
#  [0.9  0.1 ]
#  [0.63 0.37]
#  [1.   0.  ]
#  [0.99 0.01]
#  [0.98 0.02]
#  [0.94 0.06]
#  [0.12 0.88]
#  [0.88 0.12]]

# %%
from sklearn.metrics import roc_auc_score

roc_auc = roc_auc_score(y_val, pred[:,1])
print('roc_auc: ', roc_auc)
# Out:
# roc_auc:  0.9173623004487484

# %%
pred = rf.predict(X_val)
pred[:10]
# Out:
# array(['<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K',
#        '<=50K', '>50K', '<=50K'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_val, pred)
print('accuracy_score: ', accuracy)
# Out:
# accuracy_score:  0.8694761986009213

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_val, pred, pos_label='>50K')
print('f1_score: ', f1)
# Out:
# f1_score:  0.6926476496584973

# %%
# pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\lgdxschool2\anaconda3\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\lgdxschool2\anaconda3\lib\site-packages (from lightgbm) (1.13.1)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 25.3 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb
lgbmc = lgb.LGBMClassifier(random_state=0, verbose=-1) # verbose=-1 : 로그 메시지 숨기기
lgbmc.fit(X_train,y_train)
pred = lgbmc.predict_proba(X_val)

roc_auc = roc_auc_score(y_val, pred[:,1])
print('roc_auc:', roc_auc)

pred = lgbmc.predict(X_val)
accuracy = accuracy_score(y_val, pred)
print('accuracy_score:', accuracy)

f1 = f1_score(y_val,pred, pos_label='>50K')
print('f1_score:', f1)
# Out:
# roc_auc: 0.9279535666686397
# accuracy_score: 0.8771540692714553
# f1_score: 0.7158642462509865

# %%
pred = lgbmc.predict_proba(test)
pred
# Out:
# array([[0.89924007, 0.10075993],
#        [0.97622077, 0.02377923],
#        [0.9853122 , 0.0146878 ],
#        ...,
#        [0.93528667, 0.06471333],
#        [0.98996872, 0.01003128],
#        [0.96723292, 0.03276708]])

# %%
submit = pd.DataFrame({'pred':pred[:,1]})
submit.to_csv("result.csv", index=False)

# %%
pd.read_csv("result.csv")
# Out:
#           pred
# 0     0.100760
# 1     0.023779
# 2     0.014688
# 3     0.798048
# 4     0.026542
# ...        ...
# 3252  0.009613
# 3253  0.321992
# 3254  0.064713
# 3255  0.010031
# 3256  0.032767
#
# [3257 rows x 1 columns]
