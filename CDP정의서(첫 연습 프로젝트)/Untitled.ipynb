# %%
import requests as req
from bs4 import BeautifulSoup as bs
import os

# %%
head = {"":
""}

# %%
# 헤더 설정
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Referer': 'https://www.danawa.com/'
}

# 요청 보내기
res = req.get('https://search.danawa.com/dsearch.php?query=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&originalQuery=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&checkedInfo=N&volumeType=allvs&page=1&limit=40&sort=saveDESC&list=list&boost=true&tab=main&addDelivery=N&coupangMemberSort=N&simpleDescOpen=Y&mode=simple&isInitTireSmartFinder=N&recommendedSort=N&defaultUICategoryCode=102738&defaultPhysicsCategoryCode=118%7C11420%7C37175%7C0&defaultVmTab=636&defaultVaTab=169312&isZeroPrice=Y&quickProductYN=N&priceUnitSort=N&priceUnitSortOrder=A', headers=headers)

# %%
soup = bs(res.text, "lxml")

# %%
#productItem18775037 > div > div.prod_info > p > a

# %%
link = soup.select("div > div.prod_info > p > a")
link
# Out:
# [<a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=18775037&amp;keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&amp;cate=102738" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><b>LG</b>전자 퓨리케어 360˚ 플러스 AS303DWFA</a>,
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=3521947&amp;keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&amp;cate=1022486" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><b>LG</b>전자 퓨리케어 HW500DAS</a>,
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=19312541&amp;keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&amp;cate=102738" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><b>LG</b>전자 퓨리케어 360˚ Hit AS153HWWC</a>,
# ...

# %%
link_list = []
for i in link:
    link_list.append(i['href'])

# %%
link_list
# Out:
# ['https://prod.danawa.com/info/?pcode=18775037&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=3521947&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=1022486',
#  'https://prod.danawa.com/info/?pcode=19312541&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=34738973&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=19312682&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=3521853&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=1022486',
#  'https://prod.danawa.com/info/?pcode=34738895&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=18774977&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
# ...

# %%
# 페이지별로 링크 수집
href_list = []
for page in range(1, 11):
    url = f"https://search.danawa.com/dsearch.php?query=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&originalQuery=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&checkedInfo=N&volumeType=allvs&page={page}&limit=40&sort=saveDESC&list=list&boost=true&tab=goods&addDelivery=N&coupangMemberSort=N&simpleDescOpen=Y&mode=simple&isInitTireSmartFinder=N&recommendedSort=N&defaultUICategoryCode=102738&defaultPhysicsCategoryCode=118%7C11420%7C37175%7C0&defaultVmTab=636&defaultVaTab=169312&isZeroPrice=Y&quickProductYN=N&priceUnitSort=N&priceUnitSortOrder=A"
    res = req.get(url, headers=headers)
    link = soup.select(" div > div.prod_info > p > a")
    for j in link:
       href_list.append(f"{j['href']}")
href_list
# Out:
# ['https://prod.danawa.com/info/?pcode=18775037&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=3521947&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=1022486',
#  'https://prod.danawa.com/info/?pcode=19312541&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=34738973&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=19312682&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=3521853&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=1022486',
#  'https://prod.danawa.com/info/?pcode=34738895&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
#  'https://prod.danawa.com/info/?pcode=18774977&keyword=lg+%EA%B3%B5%EA%B8%B0%EC%B2%AD%EC%A0%95%EA%B8%B0&cate=102738',
# ...

# %%
# 리뷰 긁어기기

# %%
# link_list [0]번 리뷰 
res = req.get(link_list[0],headers = headers)

# %%
# 데이터 파싱
soup = bs(res.text, 'lxml')
soup

# %%
# 셀렉터
soup.select('#danawa-prodBlog-companyReview-content-wrap-0 > div.atc_cont > div.atc')
# Out:
# []
